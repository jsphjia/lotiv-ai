# %% [markdown]
# # Mount Google Drive
# Use Google Colab's `drive` module to mount Google Drive for accessing datasets and saving models.

# %%
from google.colab import drive

drive.mount('/content/drive')

# %% [markdown]
# # Import Required Libraries
# Import necessary libraries such as TensorFlow, NumPy, pandas, and matplotlib.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset
# Load the dataset from Google Drive or a public URL using pandas or TensorFlow's dataset utilities.

# %%
# Example: Load dataset from Google Drive
# Replace 'path_to_dataset' with the actual path to your dataset in Google Drive
dataset_path = '/content/drive/My Drive/path_to_dataset.csv'
data = pd.read_csv(dataset_path)

# Display the first few rows of the dataset
data.head()
